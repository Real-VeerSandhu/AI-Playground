# %%
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-117f7d79e63d> in <module>
#       1 model.compile(optimizer='adam',
# ----> 2               loss=loss_fn,
#       3               metrics=['accuracy'])
#
# NameError: name 'loss_fn' is not defined

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 58us/sample - loss: 0.2923 - accuracy: 0.9143
# Epoch 2/5
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1415 - accuracy: 0.9582
# Epoch 3/5
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.1066 - accuracy: 0.9675
# Epoch 4/5
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0867 - accuracy: 0.9732
# Epoch 5/5
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0747 - accuracy: 0.9760

# %%
model.evaluate(x_test, y_test, verbose=2)
# Out:
# 10000/10000 - 1s - loss: 0.0769 - accuracy: 0.9767
# [0.07694774722578004, 0.9767]

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])

# %%
plt.figure()
plt.imshow(x_test[4])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
x = probability_model.predict(x_test[4:5])

# %%
np.argmax(x)
# Out:
# 4

# %%
plt.figure()
plt.imshow(x_test[18])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
np.argmax(model.predict(x_test[18:19]))
# Out:
# 3

# %%
plt.figure()
plt.imshow(x_test[69])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
np.argmax(model.predict(x_test[69:70]))
# Out:
# 0

# %%
model.save('seq_model_final.h5')
